# %%
from businesslayer import Business

source_db = "mysql+pymysql://root:seif@localhost:3306/Extraction"
bus = Business(source_engine=source_db)

bus.create_fact_sales()
bus.create_fact_inventory("E:\\ITI 9 Months\\Python\\bicycle-store-etl-pipeline\\source\\products.csv", "E:\\ITI 9 Months\\Python\\bicycle-store-etl-pipeline\\source\\stocks.csv")
# Out:
#      store_id  product_id                              product_name  brand_id  \
# 0           1           1                           Trek 820 - 2016         9
# 1           1           2        Ritchey Timberwolf Frameset - 2016         5
# 2           1           3           Surly Wednesday Frameset - 2016         8
# 3           1           4                  Trek Fuel EX 8 29 - 2016         9
# 4           1           5              Heller Shagamaw Frame - 2016         3
# ..        ...         ...                                       ...       ...
# 973         3         309         Electra Townie Commute 27D - 2018         1
# 974         3         310  Electra Townie Commute 27D Ladies - 2018         1
# 975         3         311          Electra Townie Commute 8D - 2018         1
# 976         3         312  Electra Townie Commute 8D Ladies' - 2018         1
# 977         3         313  Electra Townie Original 1 Ladies' - 2018         1
#
# ...
