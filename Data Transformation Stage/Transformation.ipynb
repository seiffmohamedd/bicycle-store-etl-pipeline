# %%
# -	 Delivery Metrics: Add columns to track delivery performance, such as late deliveries and late-trip days.

from Transformation import Transformation


table_name= 'orders'
engine= 'mysql+pymysql://root:seif@localhost:3306/Extraction'


trs = Transformation(table_name , engine)
trs.create_engine()
df = trs.read_from_sql(table_name)


trs.track_delivery_performance(table_name)
# Out:
#       order_id  customer_id  order_status  order_date required_date  \
# 0            1          259             4  2016-01-01    2016-01-03
# 1            2         1212             4  2016-01-01    2016-01-04
# 2            3          523             4  2016-01-02    2016-01-05
# 3            4          175             4  2016-01-03    2016-01-04
# 4            5         1324             4  2016-01-03    2016-01-06
# ...        ...          ...           ...         ...           ...
# 1610      1611            6             3  2018-09-06    2018-09-06
# 1611      1612            3             3  2018-10-21    2018-10-21
# 1612      1613            1             3  2018-11-18    2018-11-18
# 1613      1614          135             3  2018-11-28    2018-11-28
# 1614      1615          136             3  2018-12-28    2018-12-28
#
#      shipped_date  store_id  staff_id source Extracted_date track_performance  \
# ...

# %%
# -	Lookup Tables: Resolve ambiguous columns in orders data by creating and utilizing lookup tables for order statuses.

from Transformation import Transformation


table_name= 'orders'
engine= 'mysql+pymysql://root:seif@localhost:3306/Extraction'

trs = Transformation(table_name , engine)
trs.create_engine()
trs.lookup_order_status_num('lookup.csv', table_name)
# Out:
#       order_id  customer_id order_status  order_date required_date  \
# 0            1          259    Completed  2016-01-01    2016-01-03
# 1            2         1212    Completed  2016-01-01    2016-01-04
# 2            3          523    Completed  2016-01-02    2016-01-05
# 3            4          175    Completed  2016-01-03    2016-01-04
# 4            5         1324    Completed  2016-01-03    2016-01-06
# ...        ...          ...          ...         ...           ...
# 1610      1611            6     Rejected  2018-09-06    2018-09-06
# 1611      1612            3     Rejected  2018-10-21    2018-10-21
# 1612      1613            1     Rejected  2018-11-18    2018-11-18
# 1613      1614          135     Rejected  2018-11-28    2018-11-28
# 1614      1615          136     Rejected  2018-12-28    2018-12-28
#
#      shipped_date  store_id  staff_id source Extracted_date track_performance  \
# 0      2016-01-03         1         2  mysql     2025-04-14          00:00:00
# ...

# %%
#
from Transformation import Transformation


table_name= 'orders'
engine= 'mysql+pymysql://root:seif@localhost:3306/Extraction'

trs = Transformation(table_name , engine)
trs.create_engine()

trs.add_locality_flag("orders", "E:\\ITI 9 Months\\Python\\bicycle-store-etl-pipeline\\Extraction\\customers.csv", "E:\\ITI 9 Months\\Python\\bicycle-store-etl-pipeline\\Extraction\\stores.csv")
# Out:
#       order_id  customer_id order_status  order_date required_date  \
# 0            1          259    Completed  2016-01-01    2016-01-03
# 1            2         1212    Completed  2016-01-01    2016-01-04
# 2            3          523    Completed  2016-01-02    2016-01-05
# 3            4          175    Completed  2016-01-03    2016-01-04
# 4            5         1324    Completed  2016-01-03    2016-01-06
# ...        ...          ...          ...         ...           ...
# 1610      1611            6     Rejected  2018-09-06    2018-09-06
# 1611      1612            3     Rejected  2018-10-21    2018-10-21
# 1612      1613            1     Rejected  2018-11-18    2018-11-18
# 1613      1614          135     Rejected  2018-11-28    2018-11-28
# 1614      1615          136     Rejected  2018-12-28    2018-12-28
#
#      shipped_date  store_id  staff_id source Extracted_date track_performance  \
# 0      2016-01-03         1         2  mysql     2025-04-14          00:00:00
# ...
