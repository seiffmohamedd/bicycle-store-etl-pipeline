# %%
# -	 Delivery Metrics: Add columns to track delivery performance, such as late deliveries and late-trip days.

from Transformation import Transformation


table_name= 'orders'
engine= 'mysql+pymysql://root:seif@localhost:3306/source'

trs = Transformation(table_name , engine)

df = trs.read_from_sql(table_name)


trs.track_delivery_performance(table_name)
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 1610     True
# 1611     True
# 1612     True
# 1613     True
# 1614     True
# Name: delivery_on_required, Length: 1615, dtype: bool
#       order_id  customer_id  order_status  order_date required_date  \
# 0            1          259             4  2016-01-01    2016-01-03
# 1            2         1212             4  2016-01-01    2016-01-04
# 2            3          523             4  2016-01-02    2016-01-05
# 3            4          175             4  2016-01-03    2016-01-04
# 4            5         1324             4  2016-01-03    2016-01-06
# ...        ...          ...           ...         ...           ...
# 1610      1611            6             3  2018-09-06    2018-09-06
# 1611      1612            3             3  2018-10-21    2018-10-21
# 1612      1613            1             3  2018-11-18    2018-11-18
# ...

# %%
# -	Lookup Tables: Resolve ambiguous columns in orders data by creating and utilizing lookup tables for order statuses.

from Transformation import Transformation


table_name= 'orders'
engine= 'mysql+pymysql://root:seif@localhost:3306/source'

trs = Transformation(table_name , engine)

trs.lookup_order_status_num("lookup.csv" , "orders.csv")
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[1], line 11
#       7 engine= 'mysql+pymysql://root:seif@localhost:3306/source'
#       9 trs = Transformation(table_name , engine)
# ---> 11 trs.lookup_order_status_num("lookup.csv" , "orders.csv")
#
# File e:\ITI 9 Months\Python\Days\Use Case\Transformation.py:62, in Transformation.lookup_order_status_num(self, csv_file_name, csv_file_name2)
#      59 df1=self.read_from_csv(csv_file_name)
#      60 df2=self.read_from_csv(csv_file_name2)
# ---> 62 new_df= df1.merge(df2 , how="right")
#      63 # df2["order_status"]= df[""]
#      64 print(new_df)
#
# ...
